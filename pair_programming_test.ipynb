# %% [markdown]
# ### Since the function uses user inputs, test cases will require the user to enter the same inputs that are used in the case.

# %%
import pair_programming as pp

# %%
testFeet = 5
testInches = 11

print(f"Testing with {testFeet} feet and {testInches} inches...")
if pp.mericaToMetric() - (testFeet * 0.3048 + testInches * 0.0254) < 1e-10:  # Using a small tolerance for floating-point comparison
    print("Test passed!")
else:
    print("Test failed.")
# Out:
# Testing with 5 feet and 11 inches...
# Test passed!

# %%
testFeet = 6
testInches = 4

print(f"Testing with {testFeet} feet and {testInches} inches...")
if pp.mericaToMetric() - (testFeet * 0.3048 + testInches * 0.0254) < 1e-10:  # Using a small tolerance for floating-point comparison
    print("Test passed!")
else:
    print("Test failed.")
# Out:
# Testing with 6 feet and 4 inches...
# Test passed!
